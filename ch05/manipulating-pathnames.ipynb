# %%
# %load_ext pycodestyle_magic
# %load_ext mypy_ipython
# %pycodestyle_on

# %%
import doctest

# %%
from pathlib import Path

"""

>>> p = Path('/etc/ldap/ldap.conf')
>>> p.name
'ldap.conf'
>>> p.parent
PosixPath('/etc/ldap')
>>> p.parent.joinpath('bak', 'ldap.~conf')
PosixPath('/etc/ldap/bak/ldap.~conf')
>>> Path('~').expanduser(), Path.home()
(PosixPath('/root'), PosixPath('/root'))
>>> p.stem, p.suffix, p.suffixes
('ldap', '.conf', ['.conf'])
"""

doctest.testmod()
# Out:
# TestResults(failed=0, attempted=6)

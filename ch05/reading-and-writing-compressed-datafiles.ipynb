# %%
# %load_ext pycodestyle_magic
# %load_ext mypy_ipython
# %pycodestyle_on

# %%
import doctest

# %%
import gzip
from io import BytesIO

with gzip.open('sample.tar.gz', 'rt') as f:
    text = f.read()

print(text)
# Out:
# sample.bin0000644000000000000000000000001113775242654011536 0ustar  rootrootJalapeñosample.txt0000644000000000000000000000001113775242654011605 0ustar  rootrootJalapeño

# %%
import gzip

f = open('sample.tar.gz', 'rb')
with gzip.open(f, 'rt') as g:
    text = g.read()

print(text)
# Out:
# sample.bin0000644000000000000000000000001113775242654011536 0ustar  rootrootJalapeñosample.txt0000644000000000000000000000001113775242654011605 0ustar  rootrootJalapeño
